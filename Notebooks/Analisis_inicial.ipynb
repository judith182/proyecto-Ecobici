# %%
import pandas as pd

# %%
pd.read_csv('./../data/2023-05.csv')
# Out:
#        Genero_Usuario  Edad_Usuario     Bici Ciclo_Estacion_Retiro  \
# 0                   M          29.0  7689680                   409
# 1                   F          26.0  4491841                   409
# 2                   M          53.0  8475519                   078
# 3                   F          44.0  8584393                   054
# 4                   M          23.0  6810659                   196
# ...               ...           ...      ...                   ...
# 945158              F          29.0  3319944                   068
# 945159              F          31.0  6395594                   141
# 945160              M          59.0  2152262                   167
# 945161              M          32.0  6059604                   359
# 945162              M          34.0  7220593                   004
#
#        Fecha_Retiro    Hora_Retiro Ciclo_EstacionArribo Fecha Arribo  \
# 0        30/04/2023  23:47:13.5490                  372   01/05/2023
# ...
